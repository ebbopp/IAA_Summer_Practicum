# %%
import pandas as pd
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
os.chdir("../data")

folders = ['future_rates']
save_folder = "combined_csvs"

os.makedirs(save_folder, exist_ok=True)

for folder in folders:
    save_path = os.path.join(save_folder, f"{folder}.csv")
    combined_df = pd.DataFrame()

    for filename in os.listdir(folder):
        full_path = os.path.join(folder, filename)
        df = pd.read_csv(full_path)
        city = " ".join(filename.split("_")[0:-2])
        print(city)
        df["city"] = city
        combined_df = pd.concat([combined_df, df], ignore_index=True)
        
    combined_df.to_csv(save_path, index=False)
# Out:
# myrtle beach
# raleigh
# asheville
# williamsburg
# carolina beach
# pigeon forge
# wilmington
# gatlinburg
# charlotte
# durham

# %%
os.chdir("../data")

folders = ['reviews']
save_folder = "combined_csvs"

os.makedirs(save_folder, exist_ok=True)

for folder in folders:
    save_path = os.path.join(save_folder, f"{folder}.csv")
    combined_df = pd.DataFrame()

    for filename in os.listdir(folder):
        full_path = os.path.join(folder, filename)
        df = pd.read_csv(full_path)
        city = " ".join(filename.split("_")[0:-1])
        print(city)
        df["city"] = city
        combined_df = pd.concat([combined_df, df], ignore_index=True)
        
    combined_df.to_csv(save_path, index=False)
# Out:
# raleigh
# charlotte
# carolina beach
# pigeon forge
# wilmington
# williamsburg
# durham
# asheville
# myrtle beach
# gatlinburg

# %%
os.chdir("../data")

folders = ['listings']
save_folder = "combined_csvs"

os.makedirs(save_folder, exist_ok=True)

for folder in folders:
    save_path = os.path.join(save_folder, f"{folder}.csv")
    combined_df = pd.DataFrame()

    for filename in os.listdir(folder):
        full_path = os.path.join(folder, filename)
        df = pd.read_csv(full_path, escapechar="\\")
        city = " ".join(filename.split("_")[0:-1])
        print(city)
        df["city"] = city
        combined_df = pd.concat([combined_df, df], ignore_index=True)
        
    combined_df.to_csv(save_path, index=False)
# Out:
# raleigh
# pigeon forge
# myrtle beach
# williamsburg
# wilmington
# durham
# asheville
# carolina beach
# charlotte
# gatlinburg

# %%
os.chdir("../data")

folders = ['past_rates']
save_folder = "combined_csvs"

os.makedirs(save_folder, exist_ok=True)

for folder in folders:
    save_path = os.path.join(save_folder, f"{folder}.csv")
    combined_df = pd.DataFrame()

    for filename in os.listdir(folder):
        full_path = os.path.join(folder, filename)
        df = pd.read_csv(full_path, escapechar="\\")
        city = " ".join(filename.split("_")[0:-2])
        print(city)
        df["city"] = city
        combined_df = pd.concat([combined_df, df], ignore_index=True)
        
    combined_df.to_csv(save_path, index=False)
# Out:
# gatlinburg
# myrtle beach
# asheville
# wilmington
# carolina beach
# charlotte
# williamsburg
# raleigh
# pigeon forge
# durham
